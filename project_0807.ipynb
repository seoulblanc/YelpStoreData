# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Rwork/refined_data_ya.csv", delimiter=',')
df = df.drop('Unnamed: 0', axis=1)
df.head()
#df.shape
# Out:
#    성별  연령_10세단위  직업구분  지역구분       총자산     월총저축액    월총소비금액  월평균카드사용금액  \
# 0   1         2     2     4  2.046488  3.688879  4.700480    1437017
# 1   1         3     2     2  2.188594  4.787492  4.644391    3211358
# 2   2         3     2     2  2.364906  4.787492  5.703782    2932871
# 3   1         5     2     4  2.461430  3.401197  5.991465    3106659
# 4   1         4     2     2  2.343660  4.605170  5.857933    3615840
#
#        기타자산B 월저축액_저축성보험B 월저축액_청약B 노후자금융월저축액B
# 0  1000_2500          No       No         No
# 1      0_300         Yes      Yes        Yes
# 2  1000_2500         Yes      Yes         No
# 3  1000_2500          No       No         No
# 4  1000_2500          No       No         No

# %%
target = pd.read_csv('C:/Rwork/Shinhan_data_ya.csv', delimiter=',')
target.head()
target.shape
# Out:
# (17076, 35)

# %%
target01 = target['금용상품잔액_적금']
juckgeum = pd.concat([df, target01], axis=1)
juckgeum.head()
#juckgeumRe = juckgeum.dropna()
#juckgeumRe.head()
#plt.matshow(juckgeum.corr())

rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = juckgeum.corr()
corr.style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col0 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col1 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col2 {
#             background-color:  #f1ebf4;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col3 {
#             background-color:  #f4edf6;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col4 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col5 {
#             background-color:  #e0deed;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col6 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col7 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row0_col8 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col0 {
#             background-color:  #f1ebf4;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col1 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col2 {
#             background-color:  #cacee5;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col3 {
#             background-color:  #eee8f3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col4 {
#             background-color:  #80aed2;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col5 {
#             background-color:  #d2d2e7;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col6 {
#             background-color:  #80aed2;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col7 {
#             background-color:  #83afd3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row1_col8 {
#             background-color:  #dedcec;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col0 {
#             background-color:  #e6e2ef;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col1 {
#             background-color:  #d2d3e7;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col2 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col3 {
#             background-color:  #ede7f2;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col4 {
#             background-color:  #fef6fa;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col5 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col6 {
#             background-color:  #fdf5fa;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col7 {
#             background-color:  #e7e3f0;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row2_col8 {
#             background-color:  #f7f0f7;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col0 {
#             background-color:  #e6e2ef;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col1 {
#             background-color:  #efe9f3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col2 {
#             background-color:  #e7e3f0;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col3 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col4 {
#             background-color:  #fef6fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col5 {
#             background-color:  #f0eaf4;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col6 {
#             background-color:  #f8f1f8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col7 {
#             background-color:  #f2ecf5;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row3_col8 {
#             background-color:  #fdf5fa;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col0 {
#             background-color:  #ede8f3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col1 {
#             background-color:  #79abd0;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col2 {
#             background-color:  #f4eef6;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col3 {
#             background-color:  #f9f2f8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col4 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col5 {
#             background-color:  #79abd0;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col6 {
#             background-color:  #65a3cb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col7 {
#             background-color:  #83afd3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row4_col8 {
#             background-color:  #b9c6e0;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col0 {
#             background-color:  #d5d5e8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col1 {
#             background-color:  #d8d7e9;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col2 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col3 {
#             background-color:  #f4eef6;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col4 {
#             background-color:  #88b1d4;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col5 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col6 {
#             background-color:  #a8bedc;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col7 {
#             background-color:  #c6cce3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row5_col8 {
#             background-color:  #b5c4df;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col0 {
#             background-color:  #eee8f3;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col1 {
#             background-color:  #7bacd1;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col2 {
#             background-color:  #f4eef6;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col3 {
#             background-color:  #f3edf5;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col4 {
#             background-color:  #67a4cc;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col5 {
#             background-color:  #99b8d8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col6 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col7 {
#             background-color:  #89b1d4;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row6_col8 {
#             background-color:  #d4d4e8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col0 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col1 {
#             background-color:  #9ab8d8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col2 {
#             background-color:  #f2ecf5;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col3 {
#             background-color:  #fff7fb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col4 {
#             background-color:  #9fbad9;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col5 {
#             background-color:  #d4d4e8;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col6 {
#             background-color:  #a7bddb;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col7 {
#             background-color:  #023858;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row7_col8 {
#             background-color:  #e0deed;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row8_col0 {
#             background-color:  #ebe6f2;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row8_col1 {
#             background-color:  #d7d6e9;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row8_col2 {
#             background-color:  #ede7f2;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row8_col3 {
#             background-color:  #f5eff6;
#         }    #T_377581d0_9a06_11e8_8efd_d0534944dee6row8_col4 {
#             bac

# %%
juckgeumRe = juckgeum.dropna()
juckgeumRe.head()

numeric_cols = ['총자산','월총저축액','월총소비금액']
#numeric_cols = ['월총소비금액']
x_cols =  juckgeumRe[numeric_cols]

categorical_cols = ['성별','연령_10세단위','직업구분','지역구분','기타자산B','월저축액_저축성보험B','월저축액_청약B','노후자금융월저축액B']
#categorical_cols = ['직업구분']
for i in categorical_cols:
    dummies = pd.get_dummies(juckgeumRe[i])
    x_cols = pd.concat([x_cols, dummies], axis=1)

x_target = x_cols.as_matrix()

#x_cat_cols = juckgeumRe[categorical_cols].as_matrix() 

#numeric_cols = ['총자산','월총저축액','월총소비금액']
#x_numeric_cols = juckgeumRe[numeric_cols]
#x_sum = pd.concat([x_cat_cols, x_numeric_cols], axis=1)

y_target = juckgeumRe['금용상품잔액_적금']

# %%
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(x_target, y_target, test_size=0.25, random_state=12)

lr = LinearRegression()
model_value = lr.fit(X_train,y_train)
predictions = model_value.predict(X_test)

plt.scatter(predictions, y_test, s=10)
plt.xlabel("predictions")
plt.ylabel("Y_test")
#plt.plot(predictions, y_test)
plt.show()

r2 = r2_score(y_test, predictions)
print("r-squared : ", r2)

accuracy = accuracy_score(y_test, predictions.round(), normalize=False)
print('accuracy_score : ', accuracy)

print(model_value.coef_)
print(model_value.intercept_)
# Out:
# r-squared :  0.12176155120280219
# accuracy_score :  0
# [ 3.56331651e+03  5.96407545e+02  2.48455368e+01  5.16719910e+15
#   5.16719910e+15  1.16751702e+16  1.16751702e+16  1.16751702e+16
#   1.16751702e+16  1.16751702e+16 -5.90496303e+15 -5.90496303e+15
#  -5.90496303e+15 -5.90496303e+15 -5.90496303e+15 -5.90496303e+15
#  -5.90496303e+15 -3.12162608e+14 -3.12162608e+14 -3.12162608e+14
#  -3.12162608e+14 -3.12162608e+14 -1.03452292e+16 -1.03452292e+16
#  -1.03452292e+16 -1.03452292e+16 -1.03452292e+16  2.43807888e+15
#   2.43807888e+15 -1.52434459e+15 -1.52434459e+15  2.19074503e+15
#   2.19074503e+15]
# -3384493727060551.5

# %%
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt

X_train, X_test, y_train, y_test = train_test_split(x_target, y_target, test_size=0.25, random_state=12)

lm = linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
predictions = lm.predict(X_test)

plt.scatter(predictions, y_test)
plt.ylabel("True Values")
plt.xlabel("Predictions")
print ("Score", model.score(X_test, y_test))

# Create linear regression object
regr = linear_model.LinearRegression()
 
# Train the model using the training sets
regr.fit(X_train, y_train)
 
# Plot outputs
plt.plot(predictions, regr.predict(X_test), color='red',linewidth=3)

plt.show()
# Out:
# Score 0.12176155120280219
